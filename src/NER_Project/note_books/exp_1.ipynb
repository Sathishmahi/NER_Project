# %%
from datasets import load_dataset,get_dataset_config_names
import pandas as pd

# %%
subset=get_dataset_config_names("xtreme")

# %%
subset
# Out:
# ['XNLI',
#  'tydiqa',
#  'SQuAD',
#  'PAN-X.af',
#  'PAN-X.ar',
#  'PAN-X.bg',
#  'PAN-X.bn',
#  'PAN-X.de',
#  'PAN-X.el',
#  'PAN-X.en',
#  'PAN-X.es',
#  'PAN-X.et',
#  'PAN-X.eu',
#  'PAN-X.fa',
#  'PAN-X.fi',
#  'PAN-X.fr',
#  'PAN-X.he',
#  'PAN-X.hi',
#  'PAN-X.hu',
#  'PAN-X.id',
#  'PAN-X.it',
#  'PAN-X.ja',
#  'PAN-X.jv',
#  'PAN-X.ka',
#  'PAN-X.kk',
#  'PAN-X.ko',
#  'PAN-X.ml',
#  'PAN-X.mr',
#  'PAN-X.ms',
#  'PAN-X.my',
#  'PAN-X.nl',
#  'PAN-X.pt',
#  'PAN-X.ru',
#  'PAN-X.sw',
#  'PAN-X.ta',
#  'PAN-X.te',
#  'PAN-X.th',
#  'PAN-X.tl',
#  'PAN-X.tr',
#  'PAN-X.ur',
#  'PAN-X.vi',
#  'PAN-X.yo',
#  'PAN-X.zh',
#  'MLQA.ar.ar',
#  'MLQA.ar.de',
#  'MLQA.ar.vi',
#  'MLQA.ar.zh',
#  'MLQA.ar.en',
#  'MLQA.ar.es',
#  'MLQA.ar.hi',
#  'MLQA.de.ar',
#  'MLQA.de.de',
#  'MLQA.de.vi',
#  'MLQA.de.zh',
#  'MLQA.de.en',
#  'MLQA.de.es',
#  'MLQA.de.hi',
#  'MLQA.vi.ar',
#  'MLQA.vi.de',
#  'MLQA.vi.vi',
#  'MLQA.vi.zh',
#  'MLQA.vi.en',
#  'MLQA.vi.es',
#  'MLQA.vi.hi',
# ...

# %%
get_dataset_config_names()
